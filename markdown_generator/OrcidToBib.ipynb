# %%
orcid = '0000-0002-1144-8033' # Fill your orcid here

# %%
import requests

# %% [markdown]
# We use the `/works` api to list all works related to the orcid. This gives a summary of all works, so citation information is not included. We collect the `put-code` of all works to retrieve the citation information later.

# %%
response = requests.get('https://pub.orcid.org/v3.0/{}/works'.format(orcid),
                        headers={"Accept": "application/orcid+json" })
record = response.json()

# %%
record
# Out:
# {'last-modified-date': {'value': 1767030099009},
#  'group': [{'last-modified-date': {'value': 1767030099009},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.engstruct.2025.121991',
#       'external-id-normalized': {'value': '10.1016/j.engstruct.2025.121991',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2025.121991'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 200968086,
#      'created-date': {'value': 1767030099009},
#      'last-modified-date': {'value': 1767030099009},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#        'path': '0000-0001-9884-1913',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Crossref'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Testing timber columns for resistance until fire burnout: Role of thermal wave, smoldering, and active suppression'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.engstruct.2025.121991',
#         'external-id-normalized': {'value': '10.1016/j.engstruct.2025.121991',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2025.121991'},
#         'external-id-relationship': 'self'}]},
#      'url': {'value': 'https://doi.org/10.1016/j.engstruct.2025.121991'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2026'},
#       'month': {'value': '03'},
#       'day': None},
#      'journal-title': {'value': 'Engineering Structures'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/200968086',
#      'display-index': '1'}]},
#   {'last-modified-date': {'value': 1762593722598},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.istruc.2025.110629',
#       'external-id-normalized': {'value': '10.1016/j.istruc.2025.110629',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.1016/j.istruc.2025.110629'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 196374326,
#      'created-date': {'value': 1762593722598},
#      'last-modified-date': {'value': 1762593722598},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#        'path': '0000-0001-9884-1913',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Crossref'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Modeling fire resistance of timber columns: Influence of elevated-temperature material models in finite element analysis'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.istruc.2025.110629',
#         'external-id-normalized': {'value': '10.1016/j.istruc.2025.110629',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1016/j.istruc.2025.110629'},
#         'external-id-relationship': 'self'}]},
#      'url': {'value': 'https://doi.org/10.1016/j.istruc.2025.110629'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2025'},
#       'month': {'value': '12'},
#       'day': None},
#      'journal-title': {'value': 'Structures'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/196374326',
#      'display-index': '1'}]},
#   {'last-modified-date': {'value': 1747755766313},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.engstruct.2025.120542',
#       'external-id-normalized': {'value': '10.1016/j.engstruct.2025.120542',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2025.120542'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 184414295,
#      'created-date': {'value': 1747755766313},
#      'last-modified-date': {'value': 1747755766313},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#        'path': '0000-0001-9884-1913',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Crossref'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Economic impact of performance-based fire design of composite steel frame structures'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.engstruct.2025.120542',
#         'external-id-normalized': {'value': '10.1016/j.engstruct.2025.120542',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2025.120542'},
#         'external-id-relationship': 'self'}]},
#      'url': {'value': 'https://doi.org/10.1016/j.engstruct.2025.120542'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2025'},
#       'month': {'value': '09'},
#       'day': None},
#      'journal-title': {'value': 'Engineering Structures'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/184414295',
#      'display-index': '1'}]},
#   {'last-modified-date': {'value': 1737069278306},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.ress.2025.110820',
#       'external-id-normalized': {'value': '10.1016/j.ress.2025.110820',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.1016/j.ress.2025.110820'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 175932483,
#      'created-date': {'value': 1737069278306},
#      'last-modified-date': {'value': 1737069278306},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#        'path': '0000-0001-9884-1913',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Crossref'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Fragility curves for structural fire performance of various composite floor designs under natural fire'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.ress.2025.110820',
#         'external-id-normalized': {'value': '10.1016/j.ress.2025.110820',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1016/j.ress.2025.110820'},
#         'external-id-relationship': 'self'}]},
#      'url': {'value': 'https://doi.org/10.1016/j.ress.2025.110820'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2025'},
#       'month': {'value': '05'},
#       'day': None},
#      'journal-title': {'value': 'Reliability Engineering & System Safety'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/175932483',
#      'display-index': '1'}]},
#   {'last-modified-date': {'value': 1716639487184},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.firesaf.2024.104182',
#       'external-id-normalized': {'value': '10.1016/j.firesaf.2024.104182',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.1016/j.firesaf.2024.104182'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 159855064,
#      'created-date': {'value': 1716036599612},
#      'last-modified-date': {'value': 1716639487184},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#        'path': '0000-0001-9884-1913',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Crossref'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Numerical analysis of full-scale structural fire tests on composite floor systems'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.firesaf.2024.104182',
#         'external-id-normalized': {'value': '10.1016/j.firesaf.2024.104182',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1016/j.firesaf.2024.104182'},
#         'external-id-relationship': 'self'}]},
#      'url': {'value': 'https://doi.org/10.1016/j.firesaf.2024.104182'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2024'},
#       'month': {'value': '06'},
#       'day': None},
#      'journal-title': {'value': 'Fire Safety Journal'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/159855064',
#      'display-index': '0'}]},
#   {'last-modified-date': {'value': 1693031315973},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.engstruct.2023.116784',
#       'external-id-normalized': {'value': '10.1016/j.engstruct.2023.116784',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2023.116784'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 141192370,
#      'created-date': {'value': 1693031315973},
#      'last-modified-date': {'value': 1693031315973},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#        'path': '0000-0001-9884-1913',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Crossref'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Experimental and analytical study on the performance of wind turbine tower attached with particle tuned mass damper'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.engstruct.2023.116784',
#         'external-id-normalized': {'value': '10.1016/j.engstruct.2023.116784',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2023.116784'},
#         'external-id-relationship': 'self'}]},
#      'url': {'value': 'https://doi.org/10.1016/j.engstruct.2023.116784'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2023'},
#       'month': {'value': '11'},
#       'day': None},
#      'journal-title': {'value': 'Engineering Structures'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/141192370',
#      'display-index': '0'}]},
#   {'last-modified-date': {'value': 1684871906895},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.engstruct.2023.116256',
#       'external-id-normalized': {'value': '10.1016/j.engstruct.2023.116256',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2023.116256'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 135598538,
#      'created-date': {'value': 1684871906895},
#      'last-modified-date': {'value': 1684871906895},
#      'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-1144-8033',
#        'path': '0000-0002-1144-8033',
#        'host': 'orcid.org'},
#       'source-client-id': None,
#       'source-name': {'value': 'Chenzhi Ma'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Ductile fracture of dual-phase steel at elevated temperatures'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.engstruct.2023.116256',
#         'external-id-normalized': {'value': '10.1016/j.engstruct.2023.116256',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1016/j.engstruct.2023.116256'},
#         'external-id-relationship': 'self'},
#        {'external-id-type': 'issn',
#         'external-id-value': '0141-0296',
#         'external-id-normalized': {'value': '0141-0296', 'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://portal.issn.org/resource/ISSN/0141-0296'},
#         'external-id-relationship': 'part-of'}]},
#      'url': {'value': 'http://dx.doi.org/10.1016/j.engstruct.2023.116256'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2023'},
#       'month': {'value': '08'},
#       'day': None},
#      'journal-title': {'value': 'Engineering Structures'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/135598538',
#      'display-index': '1'}]},
#   {'last-modified-date': {'value': 1652415272415},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.12989/WAS.2021.33.1.103',
#       'external-id-normalized': {'value': '10.12989/was.2021.33.1.103',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': {'value': 'https://doi.org/10.12989/WAS.2021.33.1.103'},
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 112979151,
#      'created-date': {'value': 1652415254092},
#      'last-modified-date': {'value': 1652415272415},
#      'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-1144-8033',
#        'path': '0000-0002-1144-8033',
#        'host': 'orcid.org'},
#       'source-client-id': None,
#       'source-name': {'value': 'Chenzhi Ma'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'title': {'title': {'value': 'Study on the damping mechanisms of a suspended particle damper attached to a wind turbine tower'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.12989/WAS.2021.33.1.103',
#         'external-id-normalized': {'value': '10.12989/was.2021.33.1.103',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.12989/WAS.2021.33.1.103'},
#         'external-id-relationship': 'self'}]},
#      'url': {'value': 'https://doi.org/10.12989/WAS.2021.33.1.103'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2021'},
#       'month': {'value': '07'},
#       'day': {'value': '25'}},
#      'journal-title': {'value': 'Wind and Structures'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/112979151',
#      'display-index': '1'}]},
#   {'last-modified-date': {'value': 1653929437615},
#    'external-ids': {'external-id': [{'external-id-type': 'eid',
#       'external-id-value': '2-s2.0-85077050710',
#       'external-id-normalized': {'value': '2-s2.0-85077050710',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': None,
#       'external-id-relationship': 'self'},
#      {'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.engstruct.2019.110118',
#       'external-id-normalized': {'value': '10.1016/j.engstruct.2019.110118',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': None,
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 77075055,
#      'created-date': {'value': 1594398205343},
#      'last-modified-date': {'value': 1653929437615},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0002-5982-8983',
#        'path': '0000-0002-5982-8983',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Scopus - Elsevier'},
#       'assertion-origin-orcid': {'uri': 'https://orcid.org/0000-0002-1144-8033',
#        'path': '0000-0002-1144-8033',
#        'host': 'orcid.org'},
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': {'value': 'Chenzhi Ma'}},
#      'title': {'title': {'value': 'Performance and optimum design of replaceable steel strips in an innovative metallic damper'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.engstruct.2019.110118',
#         'external-id-normalized': {'value': '10.1016/j.engstruct.2019.110118',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': None,
#         'external-id-relationship': 'self'},
#        {'external-id-type': 'eid',
#         'external-id-value': '2-s2.0-85077050710',
#         'external-id-normalized': {'value': '2-s2.0-85077050710',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': None,
#         'external-id-relationship': 'self'},
#        {'external-id-type': 'isbn',
#         'external-id-value': '18737323 01410296',
#         'external-id-normalized': None,
#         'external-id-normalized-error': {'error-code': '8001',
#          'error-message': 'Cannot normalize identifier value isbn:18737323 01410296',
#          'transient': True},
#         'external-id-url': None,
#         'external-id-relationship': 'part-of'}]},
#      'url': {'value': 'http://www.scopus.com/inward/record.url?eid=2-s2.0-85077050710&partnerID=MN8TOARS'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2020'},
#       'month': None,
#       'day': None},
#      'journal-title': {'value': 'Engineering Structures'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/77075055',
#      'display-index': '0'}]},
#   {'last-modified-date': {'value': 1653929437621},
#    'external-ids': {'external-id': [{'external-id-type': 'doi',
#       'external-id-value': '10.1016/j.jcsr.2019.105745',
#       'external-id-normalized': {'value': '10.1016/j.jcsr.2019.105745',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': None,
#       'external-id-relationship': 'self'},
#      {'external-id-type': 'eid',
#       'external-id-value': '2-s2.0-85075898766',
#       'external-id-normalized': {'value': '2-s2.0-85075898766',
#        'transient': True},
#       'external-id-normalized-error': None,
#       'external-id-url': None,
#       'external-id-relationship': 'self'}]},
#    'work-summary': [{'put-code': 77075056,
#      'created-date': {'value': 1594398205501},
#      'last-modified-date': {'value': 1653929437621},
#      'source': {'source-orcid': None,
#       'source-client-id': {'uri': 'https://orcid.org/client/0000-0002-5982-8983',
#        'path': '0000-0002-5982-8983',
#        'host': 'orcid.org'},
#       'source-name': {'value': 'Scopus - Elsevier'},
#       'assertion-origin-orcid': {'uri': 'https://orcid.org/0000-0002-1144-8033',
#        'path': '0000-0002-1144-8033',
#        'host': 'orcid.org'},
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': {'value': 'Chenzhi Ma'}},
#      'title': {'title': {'value': 'Stress-strain states of welded beam-to-column connections with geometrical and metallurgical notches'},
#       'subtitle': None,
#       'translated-title': None},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1016/j.jcsr.2019.105745',
#         'external-id-normalized': {'value': '10.1016/j.jcsr.2019.105745',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': None,
#         'external-id-relationship': 'self'},
#        {'external-id-type': 'eid',
#         'external-id-value': '2-s2.0-85075898766',
#         'external-id-normalized': {'value': '2-s2.0-85075898766',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': None,
#         'external-id-relationship': 'self'},
#        {'external-id-type': 'isbn',
#         'external-id-value': '0143974X',
#         'external-id-normalized': None,
#         'external-id-normalized-error': {'error-code': '8001',
#          'error-message': 'Cannot normalize identifier value isbn:0143974X',
#          'transient': True},
#         'external-id-url': None,
#         'external-id-relationship': 'part-of'}]},
#      'url': {'value': 'http://www.scopus.com/inward/record.url?eid=2-s2.0-85075898766&partnerID=MN8TOARS'},
#      'type': 'journal-article',
#      'publication-date': {'year': {'value': '2019'},
#       'month': None,
#       'day': None},
#      'journal-title': {'value': 'Journal of Constructional Steel Research'},
#      'visibility': 'public',
#      'path': '/0000-0002-1144-8033/work/77075056',
#      'display-index': '0'}]}],
#  'path': '/0000-0002-1144-8033/works'}

# %%
put_codes = []
for work in record['group']:
    put_code = work['work-summary'][0]['put-code']
    put_codes.append(put_code)
put_code = put_codes[0]

# %% [markdown]
# We use the `/<orcid>/work/<put-code>` endpoint to retrieve the citation information for each record.

# %%
citations = []
for put_code in put_codes:
    response = requests.get('https://pub.orcid.org/v3.0/{}/work/{}'.format(orcid, put_code),
                            headers={"Accept": "application/orcid+json" })
    work = response.json()
    if work['citation'] is not None:
        citations.append(work['citation']['citation-value'])

# %%
with open('output.bib', 'w') as bibfile:
    for citation in citations:
        bibfile.write(citation)
        bibfile.write('\n')
